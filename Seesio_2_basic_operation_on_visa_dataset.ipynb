# %% [markdown]
# -dataset name in data
#
# **import the Required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the data**

# %% [markdown]
# - here we are reading  visa dataset
# - which is csv data type : coma seprated value
# - which s located in datafile folder
# - In ored to read any dataset
#     - Directory
#     - Filename
#     - type

# %%
path=r'C:\Users\pravi\Documents\Naresh-IT\Datasets\Visadataset.csv'
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1         EZYV02           Asia              Master's                  Y
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# ...          ...            ...                   ...                ...
# 18914  EZYV18915         Europe              Master's                  Y
# 18915  EZYV18916           Asia            Bachelor's                  Y
# 18916  EZYV18917  North America              Master's                  N
# 18917  EZYV18918  North America            Bachelor's                  N
# 18918  EZYV18919           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
path1=r"C:\Users\pravi\Documents\Naresh-IT\Datasets\bank.csv"

# %%
bank_df=pd.read_csv(path1)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **Data quick chakes**
#
# - head
# - tail
# - shape
# - size
# - coloumns
# - dtype
# - info
# - take
# - loc
# - iloc

# %%
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %% [markdown]
# ***head***

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# $tail$
#
# #return last  n rows

# %%
visa_df.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 18909  EZYV18910           Asia              Master's                  Y
# 18910  EZYV18911           Asia             Doctorate                  N
# 18911  EZYV18912           Asia              Master's                  Y
# 18912  EZYV18913           Asia              Master's                  Y
# 18913  EZYV18914           Asia            Bachelor's                  Y
# 18914  EZYV18915         Europe              Master's                  Y
# 18915  EZYV18916           Asia            Bachelor's                  Y
# 18916  EZYV18917  North America              Master's                  N
# 18917  EZYV18918  North America            Bachelor's                  N
# 18918  EZYV18919           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 18909                     N             3419         1997
# ...

# %% [markdown]
# $shape$

# %%
visa_df.shape
# Out:
# (18919, 12)

# %%
print(f"the number of rows are:{visa_df.shape[0]} ")
print(f"the number of colm are:{visa_df.shape[1]} ")
# Out:
# the number of rows are:18919
# the number of colm are:12

# %% [markdown]
# $size$

# %%
visa_df.size
# Out:
# 227028

# %%
print(f'{visa_df.shape[0]*visa_df.size[1]}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(f'{visa_df.shape[0]*visa_df.size[1]}')
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# $columns$

# %%
visa_df.columns

# %%
len(visa_df.columns)
# Out:
# 12

# %%
len(visa_df)
# Out:
# 18919

# %% [markdown]
# $dtype$
#
# - it will provide each columns data type
#
# - object means string data type( Categorical)
#
# - int 64, int 32,int128,float64(neumerical)
#
# - dtype always giv in series

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ***task_1***
#
# - I want to create two lists
#
# - one is categorical columns list
#
# -  second one is numerical columns list
#
# - using dtype
#
# -  whenever you want to create any list from series
#
# -  First convert the series into a dictionary

# %%
data_type=visa_df.dtypes
dict(data_type)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
list1=[]
list2=[]

for i,j in dict(data_type).items():
    if j=='object':
        list1.append(i)
    else:
        list2.append(i)
print(list1,list2)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status'] ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
list2
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
list1=[i for i,j in dict(data_type).items() if j=='object']
list2=[i for i,j in dict(data_type).items() if j!='object']
list1,list2
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
list3=[]
list4=[]
for i in dict(data_type).items():
    if j=='object':
        list3.append(i)
    else:
        list4.append(i)
print(list3,list4)
# Out:
# [('case_id', dtype('O')), ('continent', dtype('O')), ('education_of_employee', dtype('O')), ('has_job_experience', dtype('O')), ('requires_job_training', dtype('O')), ('no_of_employees', dtype('int64')), ('yr_of_estab', dtype('int64')), ('region_of_employment', dtype('O')), ('prevailing_wage', dtype('float64')), ('unit_of_wage', dtype('O')), ('full_time_position', dtype('O')), ('case_status', dtype('O'))] []

# %%
len(list3),len(list4)
# Out:
# (12, 0)

# %% [markdown]
# - if you want to create a dataframe using these two lists
# - becouse these two list are not in equal lenght
# - if you want to create a dataframe ,then we need to make two list has equal length
#
#    - then you nedd to question  yourself
#
#    - making equal length required or not
#    - if it is require how?

# %% [markdown]
# $info$

# %%
visa_df.info
# Out:
# <bound method DataFrame.info of          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1         EZYV02           Asia              Master's                  Y
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# ...          ...            ...                   ...                ...
# 18914  EZYV18915         Europe              Master's                  Y
# 18915  EZYV18916           Asia            Bachelor's                  Y
# 18916  EZYV18917  North America              Master's                  N
# 18917  EZYV18918  North America            Bachelor's                  N
# 18918  EZYV18919           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df.take
# Out:
# <bound method NDFrame.take of          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1         EZYV02           Asia              Master's                  Y
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# ...          ...            ...                   ...                ...
# 18914  EZYV18915         Europe              Master's                  Y
# 18915  EZYV18916           Asia            Bachelor's                  Y
# 18916  EZYV18917  North America              Master's                  N
# 18917  EZYV18918  North America            Bachelor's                  N
# 18918  EZYV18919           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df.loc()

# %%
visa_df.iloc()

# %% [markdown]
# **create columns dataframe**

# %%
import pandas as pd

# %%
list1=pd.DataFrame(list1,columns=['neumerical_column'])
list1.to_csv('neumerical_column.csv',index=False)
list2=pd.DataFrame(list2,columns=['categorical_column'])
list2.to_csv('categorical_column.csv',index=False)

# %%
list1
# Out:
#        neumerical_column
# 0                case_id
# 1              continent
# 2  education_of_employee
# 3     has_job_experience
# 4  requires_job_training
# 5   region_of_employment
# 6           unit_of_wage
# 7     full_time_position
# 8            case_status

# %%
list2
# Out:
#   categorical_column
# 0    no_of_employees
# 1        yr_of_estab
# 2    prevailing_wage

# %% [markdown]
# **task2**

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
list5=[]
list6=[]
for i,j in dict(visa_df.dtypes).items():
    list5.append(i)
    list6.append(j)
df=pd.DataFrame(zip(list5,list6),columns=['content','data_type'])
df
# Out:
#                   content data_type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# **Task-3**

# %% [markdown]
# ***we can create a dataframe using dictionary also***

# %%
dict1={'names':['Ashish','pravin','tarun'],
      'age':[30,20,22]}
dict1
# Out:
# {'names': ['Ashish', 'pravin', 'tarun'], 'age': [30, 20, 22]}

# %%
pd.DataFrame(dict1)
# Out:
#     names  age
# 0  Ashish   30
# 1  pravin   20
# 2   tarun   22

# %% [markdown]
# - the advantage is : No need to provide column name again
# - Automatically key behave as columns name

# %% [markdown]
# **task-4**
#
# - we have two list are avialable
# - cols,data_type
# - create a dictionary with these two
# - ans=d make a dataframe

# %%
dict2={}
dict2['content']=list5
dict2['Data_types']=list6
pd.DataFrame(dict2)
# Out:
#                   content Data_types
# 0                 case_id     object
# 1               continent     object
# 2   education_of_employee     object
# 3      has_job_experience     object
# 4   requires_job_training     object
# 5         no_of_employees      int64
# 6             yr_of_estab      int64
# 7    region_of_employment     object
# 8         prevailing_wage    float64
# 9            unit_of_wage     object
# 10     full_time_position     object
# 11            case_status     object

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # Task is
#
# - list to dataframe
# - Dictipnary to Dataframe
# - list-->Dict--->DataFrame
# - Dict--->list--->DataFrame

# %% [markdown]
# **isnull**

# %% [markdown]
# - Null means the element is missed value
# - missing values
# - isnull we are asking a question to the computer is any element missed or not?
# - then computer will give True and False
# - True: yes the value is missed
# - False: no the value not missed

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 18914    False      False                  False               False
# 18915    False      False                  False               False
# 18916    False      False                  False               False
# 18917    False      False                  False               False
# 18918    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# **isna**

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 18914    False      False                  False               False
# 18915    False      False                  False               False
# 18916    False      False                  False               False
# 18917    False      False                  False               False
# 18918    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# **info**

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18919 entries, 0 to 18918
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                18919 non-null  object
#  1   continent              18919 non-null  object
#  2   education_of_employee  18919 non-null  object
#  3   has_job_experience     18919 non-null  object
#  4   requires_job_training  18919 non-null  object
#  5   no_of_employees        18919 non-null  int64
#  6   yr_of_estab            18919 non-null  int64
#  7   region_of_employment   18919 non-null  object
#  8   prevailing_wage        18919 non-null  float64
#  9   unit_of_wage           18919 non-null  object
#  10  full_time_position     18919 non-null  object
#  11  case_status            18919 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# **Take**
#
# - first argument is : indices
# - indices will take some values in array which means in a list
# - It tries to extract the data
# - That values we provided represent columns or rows?
# - Axis=0 represent about rows
# - Axis=1 represent about colmn
# - by defoult axis mentioned as 0 zero

# %%
visa_df.take([100,200,300])
# it retrives 3 rows which having indedx 100,200,300
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([1])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified

# %%
visa_df.take([100,200,300],axis=1)
# Now this will check for 100th colmn ,200th colmn,and 300th colmn
# but roginally we have only 12 columns (0,11)
# will get error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 visa_df.take([100,200,300],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:874, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
visa_df.take([3,5,8],axis=1)

# %% [markdown]
# $slicing$

# %%
visa_df.take([2:5])

# %%
visa_df[3:5:6]

# %% [markdown]
# **loc and iloc**

# %%
visa_df.iloc[<rows>,<column>]
visa_df.iloc[start:stop,start:stop]
visa_df.iloc[start:stope:step,start:stop:step]
visa_df.iloc[[list of rows],[list of columns]]
# case-1: rows=[100,200,300] columns=[2,5,7]
case-2:

# %%
visa_df.iloc[[100:105:2,5,7]]

# %%
visa_df.iloc[[100,200,300],[2,4,7]]

# %%
visa_df.iloc[100:105,2:6]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N
#
#      no_of_employees
# 100             2227
# 101              334
# 102              224
# 103              367
# 104              306

# %%
visa_df.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[:]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1         EZYV02           Asia              Master's                  Y
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# ...          ...            ...                   ...                ...
# 18914  EZYV18915         Europe              Master's                  Y
# 18915  EZYV18916           Asia            Bachelor's                  Y
# 18916  EZYV18917  North America              Master's                  N
# 18917  EZYV18918  North America            Bachelor's                  N
# 18918  EZYV18919           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df.iloc[:,2]
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 18914       Master's
# 18915     Bachelor's
# 18916       Master's
# 18917     Bachelor's
# 18918     Bachelor's
# Name: education_of_employee, Length: 18919, dtype: object

# %%
visa_df.iloc[:,[2]]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 18914              Master's
# 18915            Bachelor's
# 18916              Master's
# 18917            Bachelor's
# 18918            Bachelor's
#
# [18919 rows x 1 columns]

# %%
visa_df.iloc[[2,5,7]] # rows
visa_df.iloc[:,[2,5,7]] # columns
visa_df.iloc[:,2] # second columns havin seres type
visa_df.iloc[:,[2]] # second index columns having dataframe type
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 18914              Master's
# 18915            Bachelor's
# 18916              Master's
# 18917            Bachelor's
# 18918            Bachelor's
#
# [18919 rows x 1 columns]

# %% [markdown]
# **loc**

# %%
visa_df.loc[[2,5,7]]
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 2  EZYV03           Asia            Bachelor's                  N
# 5  EZYV06           Asia              Master's                  Y
# 7  EZYV08  North America            Bachelor's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 5                     N             2339         2012                South
# 7                     N             3035         1924                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2      122996.8600         Year                  Y      Denied
# 5       78252.1400         Year                  Y   Certified
# 7         418.2298         Hour                  Y      Denied

# %%
visa_df.iloc[:,[2,5,7]]
visa_df.loc[:,['continent','has_job_experience']]
# Out:
#            continent has_job_experience
# 0               Asia                  N
# 1               Asia                  Y
# 2               Asia                  N
# 3               Asia                  N
# 4             Africa                  Y
# ...              ...                ...
# 18914         Europe                  Y
# 18915           Asia                  Y
# 18916  North America                  N
# 18917  North America                  N
# 18918           Asia                  Y
#
# [18919 rows x 2 columns]

# %%
import streamlit as st
st.write('my first app')
# Out:
# 2024-07-29 22:26:51.574
# ...
#   command:
#
#     streamlit run C:\Users\pravi\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
python -m streamlit run app1.py
# Out:
#   Cell In[54], line 1
#     python -m streamlit run app1.py
#               ^
# SyntaxError: invalid syntax
